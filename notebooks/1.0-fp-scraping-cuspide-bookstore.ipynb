# %%
# Importaciones necesarias
import os
import requests
import pymysql
from bs4 import BeautifulSoup
from dotenv import load_dotenv
from datetime import date
print('Setup Complete')
# Out:
# Setup Complete

# %%
# Carga las variables de entorno
load_dotenv()

# Lee las variables de entorno
host = os.getenv('DB_HOST')
user = os.getenv('DB_USERNAME')
password = os.getenv('DB_PASSWORD')

# %%
# Conexión a la base de datos MySQL
try:
    conn = pymysql.connect(host=host, user=user, password=password)
    cursor = conn.cursor()
    print("Conexión exitosa")
except Exception as e:
    print("Ocurrió un error al conectar:", e)
# Out:
# Conexión exitosa

# %%
# Ejecuta una consulta para crear la base de datos
try:
    cursor.execute('CREATE DATABASE IF NOT EXISTS cuspide')
    print("Base de datos creada con exito")
except Exception as e:
    print("Ocurrió un error al crear la base de datos:", e)
# Out:
# Base de datos creada con exito

# %%
try:
    # Usar la base de datos "cuspide"
    cursor.execute('USE cuspide')

    # Crea la tabla books
    query = """
    CREATE TABLE IF NOT EXISTS books (
        id_Libro INT AUTO_INCREMENT PRIMARY KEY,
        titulo VARCHAR(255),
        url VARCHAR(255),
        precio FLOAT,
        precio_usd FLOAT,
        precio_usd_blue FLOAT,
        fecha DATE
    )
    """

    cursor.execute(query)

    # Crea la tabla de auditoría de errores
    query = """
    CREATE TABLE IF NOT EXISTS errors (
        idError INT AUTO_INCREMENT PRIMARY KEY,
        titulo VARCHAR(255),
        url VARCHAR(255),
        fecha DATE,
        error VARCHAR(255)
    )
    """

    cursor.execute(query)

    print("Tablas creadas con exito")
except Exception as e:
    print("Ocurrió un error al crear las tablas:", e)
# Out:
# Tablas creadas con exito

# %%
# Obtiene el valor del dolar blue
try:
    url = 'https://dolarhoy.com/cotizaciondolarblue'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    dolar_blue = float(soup.find_all('div', class_='value')[1].get_text(strip=True).replace('$', ''))
    print('Valor dolar blue:', dolar_blue)
except Exception as e:
    print("Hay un problema con la solicitud:", e)
# Out:
# Valor dolar blue: 970.0

# %%
# Obtiene la página web de cuspide
try:
    url = 'https://cuspide.com/100-mas-vendidos/'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    print("Solicitud a la página web de cuspide exitosa \nExtrayendo los datos de los libros:")
except Exception as e:
    print("Hay un problema con la solicitud.", e)
# Out:
# Solicitud a la página web de cuspide exitosa
# Extrayendo los datos de los libros:

# %%
# Busca todos los elementos <h3> que contienen el título y la URL de cada libro
books = soup.find_all(
    "h3", class_="name product-title woocommerce-loop-product__title")

# %%
# Crea una lista vacía para guardar los datos de los libros
libros = []

# Crea una lista vacía para guardar los errores
errores = []

# %%
# Itera sobre cada elemento <h3> y extraemos la URL y el título
for book in books:
    link = book.find("a")  
    title = link.text  
    url = link["href"]  

    # Obtiene la página web con la descripción de cada libro
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    try:
        p = soup.find("p", class_="price product-page-price")
        span1 = p.find('span', string='$').next_sibling
        span2 = soup.find("span", style="font-size: 1.3em")
        # Obtiene el precio del libro en pesos y dolares
        precio = float(span1.get_text(strip=True).replace('.', '').replace(',', '.'))
        precio_usd = float(span2.get_text(strip=True).replace('.', '').replace(',', '.'))
        # Calcula el precio del libro en dolares blue
        precio_usd_blue = round(precio/dolar_blue, 2)
        # Obtiene la fecha actual
        fecha = date.today().isoformat()
        # Crea un diccionario con los datos del libro
        libro = {
            "titulo": title,
            "url": url,
            "precio": precio,
            "precio_usd": precio_usd,
            "precio_usd_blue": precio_usd_blue,
            "fecha": fecha
        }
        # Agrega el diccionario del libro a la lista de libros
        libros.append(libro)
        print(libro)
    except Exception as e:
        print(f"Ocurrió un error al extraer los datos del libro {title}:", e)
        # Si ocurre algún error, crear un diccionario con el error
        error = {
            "titulo": title,
            "url": url,
            "fecha": fecha,
            "error": e
        }
        # Agrega el diccionario del error a la lista de errores
        errores.append(error)
# Out:
# {'titulo': 'LA FELICIDAD', 'url': 'https://cuspide.com/producto/la-felicidad-2/', 'precio': 16900.0, 'precio_usd': 20.58, 'precio_usd_blue': 17.42, 'fecha': '2023-12-16'}
# {'titulo': 'HEARTSTOPPER 5', 'url': 'https://cuspide.com/producto/heartstopper-5/', 'precio': 8249.0, 'precio_usd': 10.05, 'precio_usd_blue': 8.5, 'fecha': '2023-12-16'}
# {'titulo': 'DESTROZA ESTE DIARIO ( A TODO COLOR )', 'url': 'https://cuspide.com/producto/destroza-este-diario-a-todo-color/', 'precio': 20200.0, 'precio_usd': 24.6, 'precio_usd_blue': 20.82, 'fecha': '2023-12-16'}
# {'titulo': 'ZENSORIALMENTE', 'url': 'https://cuspide.com/producto/zensorialmente/', 'precio': 10999.0, 'precio_usd': 13.4, 'precio_usd_blue': 11.34, 'fecha': '2023-12-16'}
# {'titulo': 'COMO SALIR DEL POZO', 'url': 'https://cuspide.com/producto/como-salir-del-pozo/', 'precio': 9999.0, 'precio_usd': 12.18, 'precio_usd_blue': 10.31, 'fecha': '2023-12-16'}
# {'titulo': 'ALAS DE SANGRE', 'url': 'https://cuspide.com/producto/alas-de-sangre/', 'precio': 21200.0, 'precio_usd': 25.82, 'precio_usd_blue': 21.86, 'fecha': '2023-12-16'}
# {'titulo': 'EL PSICOANALISTA EN LA MIRA', 'url': 'https://cuspide.com/producto/el-psicoanalista-en-la-mira/', 'precio': 15999.0, 'precio_usd': 19.49, 'precio_usd_blue': 16.49, 'fecha': '2023-12-16'}
# {'titulo': 'ESTE DOLOR NO ES MIO', 'url': 'https://cuspide.com/producto/este-dolor-no-es-mio/', 'precio': 17300.0, 'precio_usd': 21.07, 'precio_usd_blue': 17.84, 'fecha': '2023-12-16'}
# Ocurrió un error al extraer los datos del libro LO MEJOR Y LO PEOR DE INTERNET: 'NoneType' object has no attribute 'find'
# {'titulo': 'LA CASA NEVILLE . LA FORMIDABLE SEÑORITA  MANON', 'url': 'https://cuspide.com/producto/la-casa-neville-la-formidable-senorita-manon/', 'precio': 19700.0, 'precio_usd': 24.0, 'precio_usd_blue': 20.31, 'fecha': '2023-12-16'}
# {'titulo': 'ESTA ENTRE NOSOTROS', 'url': 'https://cuspide.com/producto/esta-entre-nosotros/', 'precio': 10900.0, 'precio_usd': 13.28, 'precio_usd_blue': 11.24, 'fecha': '2023-12-16'}
# {'titulo': 'ARTIFICIAL', 'url': 'https://cuspide.com/producto/artificial-2/', 'precio': 9999.0, 'precio_usd': 12.18, 'precio_usd_blue': 10.31, 'fecha': '2023-12-16'}
# {'titulo': 'EL PROBLEMA FINAL', 'url': 'https://cuspide.com/producto/el-problema-final/', 'precio': 13999.0, 'precio_usd': 17.05, 'precio_usd_blue': 14.43, 'fecha': '2023-12-16'}
# {'titulo': 'HOROSCOPO CHINO 2024', 'url': 'https://cuspide.com/producto/horoscopo-chino-2024/', 'precio': 7999.0, 'precio_usd': 9.74, 'precio_usd_blue': 8.25, 'fecha': '2023-12-16'}
# {'titulo': 'MALDITA ROMA (SERIE JULIO CESAR 2)', 'url': 'https://cuspide.com/producto/maldita-roma-serie-julio-cesar-2/', 'precio': 19999.0, 'precio_usd': 24.36, 'precio_usd_blue': 20.62, 'fecha': '2023-12-16'}
# {'titulo': 'MESSIRVE', 'url': 'https://cuspide.com/producto/messirve/', 'precio': 6999.0, 'precio_usd': 8.52, 'precio_usd_blue': 7.22, 'fecha': '2023-12-16'}
# Ocurrió un error al extraer los datos del libro HABITOS ATOMICOS: 'NoneType' object has no attribute 'find'
# {'titulo': 'OXIDO', 'url': 'https://cuspide.com/producto/oxido/', 'precio': 14999.0, 'precio_usd': 18.27, 'precio_usd_blue': 15.46, 'fecha': '2023-12-16'}
# {'titulo': 'PSICODROMO', 'url': 'https://cuspide.com/producto/psicodromo/', 'precio': 7499.0, 'precio_usd': 9.13, 'precio_usd_blue': 7.73, 'fecha': '2023-12-16'}
# {'titulo': 'HABITOS ATOMICOS ( EDICION ESPECIAL TAPA DURA )', 'url': 'https://cuspide.com/producto/habitos-atomicos-edicion-especial-tapa-dura/', 'precio': 25900.0, 'precio_usd': 31.55, 'precio_usd_blue': 26.7, 'fecha': '2023-12-16'}
# {'titulo': 'EL PODER DE LAS PALABRAS', 'url': 'https://cuspide.com/producto/el-poder-de-las-palabras/', 'precio': 13899.0, 'precio_usd': 16.93, 'precio_usd_blue': 14.33, 'fecha': '2023-12-16'}
# {'titulo': 'DESARMA ESTE LIBRO', 'url': 'https://cuspide.com/producto/desarma-este-libro/', 'precio': 4849.0, 'precio_usd': 5.91, 'precio_usd_blue': 5.0, 'fecha': '2023-12-16'}
# {'titulo': 'NUESTRA PARTE DE NOCHE', 'url': 'https://cuspide.com/producto/nuestra-parte-de-noche/', 'precio': 18600.0, 'precio_usd': 22.66, 'precio_usd_blue': 19.18, 'fecha': '2023-12-16'}
# {'titulo': 'EL VIENTO CONOCE MI NOMBRE', 'url': 'https://cuspide.com/producto/el-viento-conoce-mi-nombre/', 'precio': 13999.0, 'precio_usd': 17.05, 'precio_usd_blue': 14.43, 'fecha': '2023-12-16'}
# {'titulo': 'UNA VELADA EN LA LIBRERIA MORISAKI', 'url': 'https://cuspide.com/producto/una-velada-en-la-libreria-morisaki/', 'precio': 6500.0, 'precio_usd': 7.92, 'precio_usd_blue': 6.7, 'fecha': '2023-12-16'}
# {'titulo': 'TIEMPO DE RENACER', 'url': 'https://cuspide.com/producto/tiempo-de-renacer/', 'precio': 12599.0, 'precio_usd': 15.35, 'precio_usd_blue': 12.99, 'fecha': '2023-12-16'}
# {'titulo': 'HOLLY', 'url': 'https://cuspide.com/producto/holly/', 'precio': 18999.0, 'precio_usd': 23.14, 'precio_usd_blue': 19.59, 'fecha': '2023-12-16'}
# Ocurrió un error al extraer los datos del libro LOS JUEGOS DEL HAMBRE ( LIBRO 1 DE LA SAGA LOS JUEGOS DEL HAMBRE ): 'NoneType' object has no attribute 'find'
# {'titulo': 'LE DEDICO MI SILENCIO', 'url': 'https://cuspide.com/producto/le-dedico-mi-silencio/', 'precio': 14999.0, 'precio_usd': 18.27, 'precio_usd_blue': 15.46, 'fecha': '2023-12-16'}
# {'titulo': 'LA NUEVA VEJEZ', 'url': 'https://cuspide.com/producto/la-nueva-vejez/', 'precio': 9999.0, 'precio_usd': 12.18, 'precio_usd_blue': 10.31, 'fecha': '2023-12-16'}
# {'titulo': 'EL DIARIO DE LA ABUELA RITA', 'url': 'https://cuspide.com/producto/el-diario-de-la-abuela-rita/', 'precio': 6399.0, 'precio_usd': 7.79, 'precio_usd_blue': 6.6, 'fecha': '2023-12-16'}
# {'titulo': 'MIS DIAS EN LA LIBRERIA MORISAKI', 'url': 'https://cuspide.com/producto/mis-dias-en-la-libreria-morisaki/', 'precio': 7390.0, 'precio_usd': 9.0, 'precio_usd_blue': 7.62, 'fecha': '2023-12-16'}
# {'titulo': "LOS OJOS PLATA  FIVE NIGHTS AT FREDDY'S", 'url': 'https://cuspide.com/producto/los-ojos-plata-five-nights-at-freddys/', 'precio': 12799.0, 'precio_usd': 15.59, 'precio_usd_blue': 13.19, 'fecha': '2023-12-16'}
# {'titulo': 'EL HOMBRE EN BUSCA DE SENTIDO', 'url': 'https://cuspide.com/producto/el-hombre-en-busca-de-sentido/', 'precio': 9900.0, 'precio_usd': 12.06, 'precio_usd_blue': 10.21, 'fecha': '2023-12-16'}
# {'titulo': 'GATURRO DE ORO 3', 'url': 'https://cuspide.com/producto/gaturro-de-oro-3/', 'precio': 5999.0, 'precio_usd': 7.31, 'precio_usd_blue': 6.18, 'fecha': '2023-12-16'}
# {'titulo': 'LOS OJOS DE PLATA - LA NOVELA GRAFICA', 'url': 'https://cuspide.com/producto/los-ojos-de-plata-la-novela-grafica/', 'precio': 12999.0, 'precio_usd': 15.83, 'precio_usd_blue': 13.4, 'fecha': '2023-12-16'}
# {'titulo': 'EL DUELO ( CUANDO EL DOLOR SE HACE CARNE )', 'url': 'https://cuspide.com/producto/el-duelo-cuando-el-dolor-se-hace-carne/', 'precio': 13900.0, 'precio_usd': 16.93, 'precio_usd_blue': 14.33, 'fecha': '2023-12-16'}
# {'titulo': 'DIBU MARTINEZ : PASION POR EL FUTBOL', 'url': 'https://cuspide.com/producto/dibu-martinez-pasion-por-el-futbol/', 'precio': 6699.0, 'precio_usd': 8.16, 'precio_usd_blue': 6.91, 'fecha': '2023-12-16'}
# {'titulo': 'UNA FAMILIA ANORMAL', 'url': 'https://cuspide.com/producto/una-familia-anormal-5/', 'precio': 5799.0, 'precio_usd': 7.06, 'precio_usd_blue': 5.98, 'fecha': '2023-12-16'}
# {'titulo': 'IKIGAI  VINTAGE', 'url': 'https://cuspide.com/producto/ikigai-vintage/', 'precio': 9150.0, 'precio_usd': 11.14, 'precio_usd_blue': 9.43, 'fecha': '2023-12-16'}
# {'titulo': 'EL MONJE QUE VENDIO SU FERRARI', 'url': 'https://cuspide.com/producto/el-monje-que-vendio-su-ferrari-2/', 'precio': 9499.0, 'precio_usd': 11.57, 'precio_usd_blue': 9.79, 'fecha': '2023-12-16'}
# {'titulo': 'ANTES DE QUE SE ENFRIE EL CAFE', 'url': 'https://cuspide.com/producto/antes-de-que-se-enfrie-el-cafe/', 'precio': 12799.0, 'precio_usd': 15.59, 'precio_usd_blue': 13.19, 'fecha': '2023-12-16'}
# {'titulo': 'PERCY JACKSON Y EL CALIZ DE LOS DIOSES', 'url': 'https://cuspide.com/producto/percy-jackson-y-el-caliz-de-los-dioses/', 'precio': 12799.0, 'precio_usd': 15.59, 'precio_usd_blue': 13.19, 'fecha': '2023-12-16'}
# {'titulo': 'LA MUJER QUE SOY', 'url': 'https://cuspide.com/producto/la-mujer-que-soy/', 'precio': 8999.0, 'precio_usd': 10.96, 'precio_usd_blue': 9.28, 'fecha': '2023-12-16'}
# {'titulo': 'NOSOTROS DOS EN LA TORMENTA', 'url': 'https://cuspide.com/producto/nosotros-dos-en-la-tormenta/', 'precio': 15999.0, 'precio_usd': 19.49, 'precio_usd_blue': 16.49, 'fecha': '2023-12-16'}
# {'titulo': 'LOS CUATRO ACUERDOS', 'url': 'https://cuspide.com/producto/los-cuatro-acuerdos/', 'precio': 10690.0, 'precio_usd': 13.02, 'precio_usd_blue': 11.02, 'fecha': '2023-12-16'}
# {'titulo': 'ESCRIBIR UN SILENCIO', 'url': 'https://cuspide.com/producto/escribir-un-silencio/', 'precio': 12999.0, 'precio_usd': 15.83, 'precio_usd_blue': 13.4, 'fecha': '2023-12-16'}
# {'titulo': 'EL CAMINO DEL ARTISTA', 'url': 'https://cuspide.com/producto/el-camino-del-artista/', 'precio': 13899.0, 'precio_usd': 16.93, 'precio_usd_blue': 14.33, 'fecha': '2023-12-16'}
# {'titulo': 'LOS ARBOLES CAIDOS TAMBIEN SON DEL BOSQUE.', 'url': 'https://cuspide.com/producto/los-arboles-caidos-tambien-son-del-bosque/', 'precio': 6840.0, 'precio_usd': 8.33, 'precio_usd_blue': 7.05, 'fecha': '2023-12-16'}
# {'titulo': 'TEMAS DE SIEMPRE', 'url': 'https://cuspide.com/producto/temas-de-siempre/', 'precio': 16500.0, 'precio_usd': 20.1, 'precio_usd_blue': 17.01, 'fecha': '2023-12-16'}
# {'titulo': 'COMPAS 10 LOS COMPAS Y EL FIN DEL MULTIVERSO', 'url': 'https://cuspide.com/producto/compas-10-los-compas-y-el-fin-del-multiverso/', 'precio': 16800.0, 'precio_usd': 20.46, 'precio_usd_blue': 17.32, 'fecha': '2023-12-16'}
# {'titulo': 'CUANDO NO QUEDEN MAS ESTRELLAS QUE CONTAR', 'url': 'https://cuspide.com/producto/cuando-no-queden-mas-estrellas-que-contar/', 'precio': 10800.0, 'precio_usd': 13.15, 'precio_usd_blue': 11.13, 'fecha': '2023-12-16'}
# {'titulo': 'LOS SIETE MARIDOS DE EVELYN HUGO', 'url': 'https://cuspide.com/producto/los-siete-maridos-de-evelyn-hugo/', 'precio': 13550.0, 'precio_usd': 16.5, 'precio_usd_blue': 13.97, 'fecha': '2023-12-16'}
# Ocurrió un error al extraer los datos del libro EL SUTIL ARTE DE QUE ( CASI TODO ) TE IMPORTE UNA MIERDA: 'NoneType' object has no attribute 'find'
# Ocurrió un error al extraer los datos del libro TAYLOR : FROM THE VAULT: 'NoneType' object has no attribute 'find'
# {'titulo': 'TRILOGIA', 'url': 'https://cuspide.com/producto/trilogia/', 'precio': 11600.0, 'precio_usd': 14.13, 'precio_usd_blue': 11.96, 'fecha': '2023-12-16'}
# {'titulo': 'JULIO CORTAZAR Y CRIS', 'url': 'https://cuspide.com/producto/julio-cortazar-y-cris/', 'precio': 11090.0, 'precio_usd': 13.51, 'precio_usd_blue': 11.43, 'fecha': '2023-12-16'}
# {'titulo': 'FORTUNA', 'url': 'https://cuspide.com/producto/fortuna/', 'precio': 13800.0, 'precio_usd': 16.81, 'precio_usd_blue': 14.23, 'fecha': '2023-12-16'}
# Ocurrió un error al extraer los datos del libro SI LO CREES , LO CREAS: 'NoneType' object has no attribute 'find'
# Ocurrió un error al extraer los datos del libro DEJA DE SER TU: 'NoneType' object has no attribute 'find'
# {'titulo': 'CLASES DE LITERATURA RUSA', 'url': 'https://cuspide.com/producto/clases-de-literatura-rusa/', 'precio': 12999.0, 'precio_usd': 15.83, 'precio_usd_blue': 13.4, 'fecha': '2023-12-16'}
# {'titulo': 'MI DESEO ES ODIARTE', 'url': 'https://cuspide.com/producto/mi-deseo-es-odiarte/', 'precio': 9650.0, 'precio_usd': 11.75, 'precio_usd_blue': 9.95, 'fecha': '2023-12-16'}
# {'titulo': 'YOLO AVENTURAS 3 LOS IMPOSTORES DEL ESPACIO', 'url': 'https://cuspide.com/producto/yolo-aventuras-3-los-impostores-del-espacio/', 'precio': 14000.0, 'precio_usd': 17.05, 'precio_usd_blue': 14.43, 'fecha': '2023-12-16'}
# {'titulo': 'POLITEIA', 'url': 'https://cuspide.com/producto/politeia-2/', 'precio': 13500.0, 'precio_usd': 16.44, 'precio_usd_blue': 13.92, 'fecha': '2023-12-16'}
# {'titulo': 'LA SCALONETA', 'url': 'https://cuspide.com/producto/la-scaloneta/', 'precio': 8490.0, 'precio_usd': 10.34, 'precio_usd_blue': 8.75, 'fecha': '2023-12-16'}
# {'titulo': 'LOS CHICOS DE BILOXI', 'url': 'https://cuspide.com/producto/los-chicos-de-biloxi/', 'precio': 17599.0, 'precio_usd': 21.44, 'precio_usd_blue': 18.14, 'fecha': '2023-12-16'}
# {'titulo': 'PADRE RICO , PADRE POBRE (25 A/OS)', 'url': 'https://cuspide.com/producto/padre-rico-padre-pobre-25-a-os/', 'precio': 10899.0, 'precio_usd': 13.28, 'precio_usd_blue': 11.24, 'fecha': '2023-12-16'}
# {'titulo': 'ENCUENTRA TU PERSONA VITAMINA', 'url': 'https://cuspide.com/producto/encuentra-tu-persona-vitamina/', 'precio': 21800.0, 'precio_usd': 26.55, 'precio_usd_blue': 22.47, 'fecha': '2023-12-16'}
# {'titulo': 'PENSAR A LA JAPONESA', 'url': 'https://cuspide.com/producto/pensar-a-la-japonesa/', 'precio': 6950.0, 'precio_usd': 8.47, 'precio_usd_blue': 7.16, 'fecha': '2023-12-16'}
# {'titulo': 'ME DESCUBRO A DIARIO', 'url': 'https://cuspide.com/producto/me-descubro-a-diario/', 'precio': 22490.0, 'precio_usd': 27.39, 'precio_usd_blue': 23.19, 'fecha': '2023-12-16'}
# {'titulo': 'LAS LUCES DE FEBRERO', 'url': 'https://cuspide.com/producto/las-luces-de-febrero/', 'precio': 14999.0, 'precio_usd': 18.27, 'precio_usd_blue': 15.46, 'fecha': '2023-12-16'}
# Ocurrió un error al extraer los datos del libro LAS NI/AS DEL NARANJEL: 'NoneType' object has no attribute 'find'
# {'titulo': 'UN VECINO ANORMAL  : Y EL LADRON DEL CHOCOLATE', 'url': 'https://cuspide.com/producto/un-vecino-anormal-y-el-ladron-del-chocolate/', 'precio': 6399.0, 'precio_usd': 7.79, 'precio_usd_blue': 6.6, 'fecha': '2023-12-16'}
# {'titulo': 'EL PRINCIPITO', 'url': 'https://cuspide.com/producto/el-principito-9/', 'precio': 3999.0, 'precio_usd': 4.87, 'precio_usd_blue': 4.12, 'fecha': '2023-12-16'}
# {'titulo': 'LA CASA DE LOS SUICIDIOS', 'url': 'https://cuspide.com/producto/la-casa-de-los-suicidios/', 'precio': 13900.0, 'precio_usd': 16.93, 'precio_usd_blue': 14.33, 'fecha': '2023-12-16'}
# {'titulo': 'LAS HIJAS DE LA CRIADA', 'url': 'https://cuspide.com/producto/las-hijas-de-la-criada/', 'precio': 18100.0, 'precio_usd': 22.05, 'precio_usd_blue': 18.66, 'fecha': '2023-12-16'}
# {'titulo': 'PENSAMIENTOS NUTRITIVOS', 'url': 'https://cuspide.com/producto/pensamientos-nutritivos/', 'precio': 8999.0, 'precio_usd': 10.96, 'precio_usd_blue': 9.28, 'fecha': '2023-12-16'}
# {'titulo': '1. HARRY POTTER Y LA PIEDRA FILOSOFAL ( BOLSILLO )', 'url': 'https://cuspide.com/producto/1-harry-potter-y-la-piedra-filosofal-bolsillo/', 'precio': 9999.0, 'precio_usd': 12.18, 'precio_usd_blue': 10.31, 'fecha': '2023-12-16'}
# {'titulo': 'PORQUE DEMASIADO NO ES SUFICIENTE', 'url': 'https://cuspide.com/producto/porque-demasiado-no-es-suficiente/', 'precio': 9990.0, 'precio_usd': 12.17, 'precio_usd_blue': 10.3, 'fecha': '2023-12-16'}
# {'titulo': 'TESIS SOBRE UNA DOMESTICACION', 'url': 'https://cuspide.com/producto/tesis-sobre-una-domesticacion/', 'precio': 18500.0, 'precio_usd': 22.53, 'precio_usd_blue': 19.07, 'fecha': '2023-12-16'}
# {'titulo': 'LA ARMADURA DE LA LUZ', 'url': 'https://cuspide.com/producto/la-armadura-de-la-luz/', 'precio': 24999.0, 'precio_usd': 30.45, 'precio_usd_blue': 25.77, 'fecha': '2023-12-16'}
# {'titulo': 'SANA A TUS ANTEPASADOS PARA SANAR TU VIDA', 'url': 'https://cuspide.com/producto/sana-a-tus-antepasados-para-sanar-tu-vida/', 'precio': 8150.0, 'precio_usd': 9.93, 'precio_usd_blue': 8.4, 'fecha': '2023-12-16'}
# Ocurrió un error al extraer los datos del libro ARTA EN EL APOCALIPSIS MAXIMO ( LIBRO 1 DE ARTA ): 'NoneType' object has no attribute 'find'
# {'titulo': 'LAS MALAS - BOOKET VERANO 2023-2024', 'url': 'https://cuspide.com/producto/las-malas-booket-verano-2023-2024/', 'precio': 9000.0, 'precio_usd': 10.96, 'precio_usd_blue': 9.28, 'fecha': '2023-12-16'}
# {'titulo': 'MESSIMANIA', 'url': 'https://cuspide.com/producto/messimania/', 'precio': 11600.0, 'precio_usd': 14.13, 'precio_usd_blue': 11.96, 'fecha': '2023-12-16'}
# {'titulo': 'LOS VESTIDOS APONI - STICKERS', 'url': 'https://cuspide.com/producto/los-vestidos-aponi-stickers/', 'precio': 7999.0, 'precio_usd': 9.74, 'precio_usd_blue': 8.25, 'fecha': '2023-12-16'}
# {'titulo': 'LA TERCERA  LOS HEROES', 'url': 'https://cuspide.com/producto/la-tercera-los-heroes/', 'precio': 12400.0, 'precio_usd': 15.1, 'precio_usd_blue': 12.78, 'fecha': '2023-12-16'}
# {'titulo': 'NOSOTROS EN LA LUNA', 'url': 'https://cuspide.com/producto/nosotros-en-la-luna-2/', 'precio': 9000.0, 'precio_usd': 10.96, 'precio_usd_blue': 9.28, 'fecha': '2023-12-16'}
# {'titulo': 'EL ETERNAUTA ( ED . ECONOMICA )', 'url': 'https://cuspide.com/producto/el-eternauta-ed-economica/', 'precio': 14300.0, 'precio_usd': 17.42, 'precio_usd_blue': 14.74, 'fecha': '2023-12-16'}
# {'titulo': 'COMETIERRA 10 EDIC', 'url': 'https://cuspide.com/producto/cometierra-10-edic/', 'precio': 9300.0, 'precio_usd': 11.33, 'precio_usd_blue': 9.59, 'fecha': '2023-12-16'}
# {'titulo': 'LA HERMANDAD DE LAS MALAS HIJAS', 'url': 'https://cuspide.com/producto/la-hermandad-de-las-malas-hijas/', 'precio': 13799.0, 'precio_usd': 16.81, 'precio_usd_blue': 14.23, 'fecha': '2023-12-16'}
# {'titulo': 'TEORIA DE LA GRAVEDAD', 'url': 'https://cuspide.com/producto/teoria-de-la-gravedad/', 'precio': 10900.0, 'precio_usd': 13.28, 'precio_usd_blue': 11.24, 'fecha': '2023-12-16'}
# {'titulo': 'BAJAR ES LO PEOR', 'url': 'https://cuspide.com/producto/bajar-es-lo-peor/', 'precio': 12350.0, 'precio_usd': 15.04, 'precio_usd_blue': 12.73, 'fecha': '2023-12-16'}
# {'titulo': 'LAS INDIGNAS', 'url': 'https://cuspide.com/producto/las-indignas/', 'precio': 8399.0, 'precio_usd': 10.23, 'precio_usd_blue': 8.66, 'fecha': '2023-12-16'}
# {'titulo': 'MUCHAS VIDAS , MUCHOS MAESTROS', 'url': 'https://cuspide.com/producto/muchas-vidas-muchos-maestros-2/', 'precio': 9499.0, 'precio_usd': 11.57, 'precio_usd_blue': 9.79, 'fecha': '2023-12-16'}
# Ocurrió un error al extraer los datos del libro BALADA DE PAJAROS CANTORES Y SERPIENTES: 'NoneType' object has no attribute 'find'
# {'titulo': 'RIVALES DIVINOS', 'url': 'https://cuspide.com/producto/rivales-divinos/', 'precio': 13790.0, 'precio_usd': 16.8, 'precio_usd_blue': 14.22, 'fecha': '2023-12-16'}
# {'titulo': 'UN ALMA DE CENIZA Y SANGRE  ( LIBRO 5 SAGA DE SANGRE Y CENIZAS )', 'url': 'https://cuspide.com/producto/un-alma-de-ceniza-y-sangre-libro-5-saga-de-sangre-y-cenizas/', 'precio': 15400.0, 'precio_usd': 18.76, 'precio_usd_blue': 15.88, 'fecha': '2023-12-16'}
# {'titulo': 'BEYOND THE STORY ( EDICION EN ESPA/OL )', 'url': 'https://cuspide.com/producto/beyond-the-story-edicion-en-espa-ol/', 'precio': 14999.0, 'precio_usd': 18.27, 'precio_usd_blue': 15.46, 'fecha': '2023-12-16'}
# {'titulo': 'TOKIO BLUES - BOOKET VERANO 2023-2024', 'url': 'https://cuspide.com/producto/tokio-blues-booket-verano-2023-2024/', 'precio': 9000.0, 'precio_usd': 10.96, 'precio_usd_blue': 9.28, 'fecha': '2023-12-16'}

# %%
# Imprime la lista de libros
print("Libros:")
for libro in libros:
    print(f"Título: {libro['titulo']}")
    print(f"URL: {libro['url']}")
    print(f"AR$: {libro['precio']}")
    print(f"U$s: {libro['precio_usd']}")
    print(f"U$s Blue: {libro['precio_usd_blue']}")
    print(f"Fecha: {libro['fecha']}")
    print()
# Out:
# Libros:
# Título: LA FELICIDAD
# URL: https://cuspide.com/producto/la-felicidad-2/
# AR$: 16900.0
# U$s: 20.58
# U$s Blue: 17.42
# Fecha: 2023-12-16
#
# Título: HEARTSTOPPER 5
# URL: https://cuspide.com/producto/heartstopper-5/
# AR$: 8249.0
# U$s: 10.05
# U$s Blue: 8.5
# Fecha: 2023-12-16
#
# Título: DESTROZA ESTE DIARIO ( A TODO COLOR )
# URL: https://cuspide.com/producto/destroza-este-diario-a-todo-color/
# AR$: 20200.0
# U$s: 24.6
# U$s Blue: 20.82
# Fecha: 2023-12-16
#
# Título: ZENSORIALMENTE
# URL: https://cuspide.com/producto/zensorialmente/
# AR$: 10999.0
# U$s: 13.4
# U$s Blue: 11.34
# Fecha: 2023-12-16
#
# Título: COMO SALIR DEL POZO
# URL: https://cuspide.com/producto/como-salir-del-pozo/
# URL: https://cuspide.com/producto/la-tercera-los-heroes/
# AR$: 12400.0
# U$s: 15.1
# U$s Blue: 12.78
# Fecha: 2023-12-16
#
# Título: NOSOTROS EN LA LUNA
# URL: https://cuspide.com/producto/nosotros-en-la-luna-2/
# AR$: 9000.0
# U$s: 10.96
# U$s Blue: 9.28
# Fecha: 2023-12-16
#
# Título: EL ETERNAUTA ( ED . ECONOMICA )
# URL: https://cuspide.com/producto/el-eternauta-ed-economica/
# AR$: 14300.0
# U$s: 17.42
# U$s Blue: 14.74
# Fecha: 2023-12-16
#
# Título: COMETIERRA 10 EDIC
# URL: https://cuspide.com/producto/cometierra-10-edic/
# AR$: 9300.0
# U$s: 11.33
# U$s Blue: 9.59
# Fecha: 2023-12-16
#
# Título: LA HERMANDAD DE LAS MALAS HIJAS
# URL: https://cuspide.com/producto/la-hermandad-de-las-malas-hijas/
# AR$: 13799.0
# U$s: 16.81
# U$s Blue: 14.23
# Fecha: 2023-12-16
#
# Título: TEORIA DE LA GRAVEDAD
# URL: https://cuspide.com/producto/teoria-de-la-gravedad/
# AR$: 10900.0
# U$s: 13.28
# U$s Blue: 11.24
# Fecha: 2023-12-16
#
# Título: BAJAR ES LO PEOR
# URL: https://cuspide.com/producto/bajar-es-lo-peor/
# AR$: 12350.0
# U$s: 15.04
# U$s Blue: 12.73
# Fecha: 2023-12-16
#
# Título: LAS INDIGNAS
# URL: https://cuspide.com/producto/las-indignas/
# AR$: 8399.0
# U$s: 10.23
# U$s Blue: 8.66
# Fecha: 2023-12-16
#
# Título: MUCHAS VIDAS , MUCHOS MAESTROS
# URL: https://cuspide.com/producto/muchas-vidas-muchos-maestros-2/
# AR$: 9499.0
# U$s: 11.57
# U$s Blue: 9.79
# Fecha: 2023-12-16
#
# Título: RIVALES DIVINOS
# URL: https://cuspide.com/producto/rivales-divinos/
# AR$: 13790.0
# U$s: 16.8
# U$s Blue: 14.22
# Fecha: 2023-12-16
#
# Título: UN ALMA DE CENIZA Y SANGRE  ( LIBRO 5 SAGA DE SANGRE Y CENIZAS )
# URL: https://cuspide.com/producto/un-alma-de-ceniza-y-sangre-libro-5-saga-de-sangre-y-cenizas/
# AR$: 15400.0
# U$s: 18.76
# U$s Blue: 15.88
# Fecha: 2023-12-16
#
# Título: BEYOND THE STORY ( EDICION EN ESPA/OL )
# URL: https://cuspide.com/producto/beyond-the-story-edicion-en-espa-ol/
# AR$: 14999.0
# U$s: 18.27
# U$s Blue: 15.46
# Fecha: 2023-12-16
#
# Título: TOKIO BLUES - BOOKET VERANO 2023-2024
# URL: https://cuspide.com/producto/tokio-blues-booket-verano-2023-2024/
# AR$: 9000.0
# U$s: 10.96
# U$s Blue: 9.28
# Fecha: 2023-12-16

# %%
# Imprime la lista de errores
print("Errores:")
for error in errores:
    print(f"Título: {error['titulo']}")
    print(f"URL: {error['url']}")
    print(f"Error: {error['error']}")
    print(f"Fecha: {error['fecha']}")
    print()
# Out:
# Errores:
# Título: LO MEJOR Y LO PEOR DE INTERNET
# URL: https://cuspide.com/producto/lo-mejor-y-lo-peor-de-internet/
# Error: 'NoneType' object has no attribute 'find'
# Fecha: 2023-12-16
#
# Título: HABITOS ATOMICOS
# URL: https://cuspide.com/producto/habitos-atomicos-2/
# Error: 'NoneType' object has no attribute 'find'
# Fecha: 2023-12-16
#
# Título: LOS JUEGOS DEL HAMBRE ( LIBRO 1 DE LA SAGA LOS JUEGOS DEL HAMBRE )
# URL: https://cuspide.com/producto/los-juegos-del-hambre-libro-1-de-la-saga-los-juegos-del-hambre/
# Error: 'NoneType' object has no attribute 'find'
# Fecha: 2023-12-16
#
# Título: EL SUTIL ARTE DE QUE ( CASI TODO ) TE IMPORTE UNA MIERDA
# URL: https://cuspide.com/producto/el-sutil-arte-de-que-casi-todo-te-importe-una-mierda/
# Error: 'NoneType' object has no attribute 'find'
# Fecha: 2023-12-16
#
# Título: TAYLOR : FROM THE VAULT
# URL: https://cuspide.com/producto/taylor-from-the-vault/
# Error: 'NoneType' object has no attribute 'find'
# Fecha: 2023-12-16
#
# Título: SI LO CREES , LO CREAS
# URL: https://cuspide.com/producto/si-lo-crees-lo-creas/
# Error: 'NoneType' object has no attribute 'find'
# Fecha: 2023-12-16
#
# Título: DEJA DE SER TU
# URL: https://cuspide.com/producto/deja-de-ser-tu/
# Error: 'NoneType' object has no attribute 'find'
# Fecha: 2023-12-16
#
# Título: LAS NI/AS DEL NARANJEL
# URL: https://cuspide.com/producto/las-ni-as-del-naranjel/
# Error: 'NoneType' object has no attribute 'find'
# Fecha: 2023-12-16
#
# Título: ARTA EN EL APOCALIPSIS MAXIMO ( LIBRO 1 DE ARTA )
# URL: https://cuspide.com/producto/arta-en-el-apocalipsis-maximo-libro-1-de-arta/
# Error: 'NoneType' object has no attribute 'find'
# Fecha: 2023-12-16
#
# Título: BALADA DE PAJAROS CANTORES Y SERPIENTES
# URL: https://cuspide.com/producto/balada-de-pajaros-cantores-y-serpientes/
# Error: 'NoneType' object has no attribute 'find'
# Fecha: 2023-12-16

# %%
# Itera sobre la lista de libros
try:
    print("Ingestando los datos de los libros en la base de datos...")
    for libro in libros:
        # Crea la consulta SQL para insertar los datos del libro
        query = f"""
        INSERT INTO books (titulo, url, precio, precio_usd, precio_usd_blue, fecha)
        VALUES ("{libro["titulo"]}", "{libro["url"]}", {libro["precio"]}, {libro["precio_usd"]}, {libro["precio_usd_blue"]}, "{libro["fecha"]}")
        """
        # Ejecuta la consulta
        cursor.execute(query)

    # Itera sobre la lista de errores
    for error in errores:
        # Crea la consulta SQL para insertar los datos del error
        query = f"""
        INSERT INTO errors (titulo, url, fecha, error)
        VALUES ("{error["titulo"]}", "{error["url"]}", "{error["fecha"]}", "{error["error"]}")
        """
        # Ejecuta la consulta
        cursor.execute(query)

    # Confirma los cambios
    conn.commit()
    print("Ingesta de datos finalizada con éxito")
    
except Exception as e:
    # Manejo de errores
    print("Ocurrió un error:", e)
# Out:
# Ingestando los datos de los libros en la base de datos...
# Ingesta de datos finalizada con éxito

# %%
try:
    # Selecciona todos los registros de la tabla books
    cursor.execute("SELECT * FROM books")
    libros = cursor.fetchall()
    print("Datos de la tabla books:")
    for libro in libros:
        print(libro)

    # Selecciona todos los registros de la tabla errors
    cursor.execute("SELECT * FROM errors")
    errores = cursor.fetchall()
    print("Datos de la tabla errors:")
    for error in errores:
        print(error)

except Exception as e:
    # Manejo de errores
    print("Ocurrió un error:", e)

finally:
    # Cerrar la conexión
    if conn:
        cursor.close()
        conn.close()
        print("Conexión cerrada")
# Out:
# Conexión exitosa
# Datos de la tabla books:
# (1, 'LA FELICIDAD', 'https://cuspide.com/producto/la-felicidad-2/', 16900.0, 20.58, 17.42, datetime.date(2023, 12, 16))
# (2, 'HEARTSTOPPER 5', 'https://cuspide.com/producto/heartstopper-5/', 8249.0, 10.05, 8.5, datetime.date(2023, 12, 16))
# (3, 'DESTROZA ESTE DIARIO ( A TODO COLOR )', 'https://cuspide.com/producto/destroza-este-diario-a-todo-color/', 20200.0, 24.6, 20.82, datetime.date(2023, 12, 16))
# (4, 'ZENSORIALMENTE', 'https://cuspide.com/producto/zensorialmente/', 10999.0, 13.4, 11.34, datetime.date(2023, 12, 16))
# (5, 'COMO SALIR DEL POZO', 'https://cuspide.com/producto/como-salir-del-pozo/', 9999.0, 12.18, 10.31, datetime.date(2023, 12, 16))
# (6, 'ALAS DE SANGRE', 'https://cuspide.com/producto/alas-de-sangre/', 21200.0, 25.82, 21.86, datetime.date(2023, 12, 16))
# (7, 'EL PSICOANALISTA EN LA MIRA', 'https://cuspide.com/producto/el-psicoanalista-en-la-mira/', 15999.0, 19.49, 16.49, datetime.date(2023, 12, 16))
# (8, 'ESTE DOLOR NO ES MIO', 'https://cuspide.com/producto/este-dolor-no-es-mio/', 17300.0, 21.07, 17.84, datetime.date(2023, 12, 16))
# (9, 'LA CASA NEVILLE . LA FORMIDABLE SEÑORITA  MANON', 'https://cuspide.com/producto/la-casa-neville-la-formidable-senorita-manon/', 19700.0, 24.0, 20.31, datetime.date(2023, 12, 16))
# (10, 'ESTA ENTRE NOSOTROS', 'https://cuspide.com/producto/esta-entre-nosotros/', 10900.0, 13.28, 11.24, datetime.date(2023, 12, 16))
# (11, 'ARTIFICIAL', 'https://cuspide.com/producto/artificial-2/', 9999.0, 12.18, 10.31, datetime.date(2023, 12, 16))
# (12, 'EL PROBLEMA FINAL', 'https://cuspide.com/producto/el-problema-final/', 13999.0, 17.05, 14.43, datetime.date(2023, 12, 16))
# (13, 'HOROSCOPO CHINO 2024', 'https://cuspide.com/producto/horoscopo-chino-2024/', 7999.0, 9.74, 8.25, datetime.date(2023, 12, 16))
# (14, 'MALDITA ROMA (SERIE JULIO CESAR 2)', 'https://cuspide.com/producto/maldita-roma-serie-julio-cesar-2/', 19999.0, 24.36, 20.62, datetime.date(2023, 12, 16))
# (15, 'MESSIRVE', 'https://cuspide.com/producto/messirve/', 6999.0, 8.52, 7.22, datetime.date(2023, 12, 16))
# (16, 'OXIDO', 'https://cuspide.com/producto/oxido/', 14999.0, 18.27, 15.46, datetime.date(2023, 12, 16))
# (17, 'PSICODROMO', 'https://cuspide.com/producto/psicodromo/', 7499.0, 9.13, 7.73, datetime.date(2023, 12, 16))
# (18, 'HABITOS ATOMICOS ( EDICION ESPECIAL TAPA DURA )', 'https://cuspide.com/producto/habitos-atomicos-edicion-especial-tapa-dura/', 25900.0, 31.55, 26.7, datetime.date(2023, 12, 16))
# (19, 'EL PODER DE LAS PALABRAS', 'https://cuspide.com/producto/el-poder-de-las-palabras/', 13899.0, 16.93, 14.33, datetime.date(2023, 12, 16))
# (20, 'DESARMA ESTE LIBRO', 'https://cuspide.com/producto/desarma-este-libro/', 4849.0, 5.91, 5.0, datetime.date(2023, 12, 16))
# (21, 'NUESTRA PARTE DE NOCHE', 'https://cuspide.com/producto/nuestra-parte-de-noche/', 18600.0, 22.66, 19.18, datetime.date(2023, 12, 16))
# (22, 'EL VIENTO CONOCE MI NOMBRE', 'https://cuspide.com/producto/el-viento-conoce-mi-nombre/', 13999.0, 17.05, 14.43, datetime.date(2023, 12, 16))
# (23, 'UNA VELADA EN LA LIBRERIA MORISAKI', 'https://cuspide.com/producto/una-velada-en-la-libreria-morisaki/', 6500.0, 7.92, 6.7, datetime.date(2023, 12, 16))
# (24, 'TIEMPO DE RENACER', 'https://cuspide.com/producto/tiempo-de-renacer/', 12599.0, 15.35, 12.99, datetime.date(2023, 12, 16))
# (25, 'HOLLY', 'https://cuspide.com/producto/holly/', 18999.0, 23.14, 19.59, datetime.date(2023, 12, 16))
# (26, 'LE DEDICO MI SILENCIO', 'https://cuspide.com/producto/le-dedico-mi-silencio/', 14999.0, 18.27, 15.46, datetime.date(2023, 12, 16))
# (27, 'LA NUEVA VEJEZ', 'https://cuspide.com/producto/la-nueva-vejez/', 9999.0, 12.18, 10.31, datetime.date(2023, 12, 16))
# (28, 'EL DIARIO DE LA ABUELA RITA', 'https://cuspide.com/producto/el-diario-de-la-abuela-rita/', 6399.0, 7.79, 6.6, datetime.date(2023, 12, 16))
# (29, 'MIS DIAS EN LA LIBRERIA MORISAKI', 'https://cuspide.com/producto/mis-dias-en-la-libreria-morisaki/', 7390.0, 9.0, 7.62, datetime.date(2023, 12, 16))
# (30, "LOS OJOS PLATA  FIVE NIGHTS AT FREDDY'S", 'https://cuspide.com/producto/los-ojos-plata-five-nights-at-freddys/', 12799.0, 15.59, 13.19, datetime.date(2023, 12, 16))
# (31, 'EL HOMBRE EN BUSCA DE SENTIDO', 'https://cuspide.com/producto/el-hombre-en-busca-de-sentido/', 9900.0, 12.06, 10.21, datetime.date(2023, 12, 16))
# (32, 'GATURRO DE ORO 3', 'https://cuspide.com/producto/gaturro-de-oro-3/', 5999.0, 7.31, 6.18, datetime.date(2023, 12, 16))
# (33, 'LOS OJOS DE PLATA - LA NOVELA GRAFICA', 'https://cuspide.com/producto/los-ojos-de-plata-la-novela-grafica/', 12999.0, 15.83, 13.4, datetime.date(2023, 12, 16))
# (34, 'EL DUELO ( CUANDO EL DOLOR SE HACE CARNE )', 'https://cuspide.com/producto/el-duelo-cuando-el-dolor-se-hace-carne/', 13900.0, 16.93, 14.33, datetime.date(2023, 12, 16))
# (35, 'DIBU MARTINEZ : PASION POR EL FUTBOL', 'https://cuspide.com/producto/dibu-martinez-pasion-por-el-futbol/', 6699.0, 8.16, 6.91, datetime.date(2023, 12, 16))
# (36, 'UNA FAMILIA ANORMAL', 'https://cuspide.com/producto/una-familia-anormal-5/', 5799.0, 7.06, 5.98, datetime.date(2023, 12, 16))
# (37, 'IKIGAI  VINTAGE', 'https://cuspide.com/producto/ikigai-vintage/', 9150.0, 11.14, 9.43, datetime.date(2023, 12, 16))
# (38, 'EL MONJE QUE VENDIO SU FERRARI', 'https://cuspide.com/producto/el-monje-que-vendio-su-ferrari-2/', 9499.0, 11.57, 9.79, datetime.date(2023, 12, 16))
# (39, 'ANTES DE QUE SE ENFRIE EL CAFE', 'https://cuspide.com/producto/antes-de-que-se-enfrie-el-cafe/', 12799.0, 15.59, 13.19, datetime.date(2023, 12, 16))
# (40, 'PERCY JACKSON Y EL CALIZ DE LOS DIOSES', 'https://cuspide.com/producto/percy-jackson-y-el-caliz-de-los-dioses/', 12799.0, 15.59, 13.19, datetime.date(2023, 12, 16))
# (41, 'LA MUJER QUE SOY', 'https://cuspide.com/producto/la-mujer-que-soy/', 8999.0, 10.96, 9.28, datetime.date(2023, 12, 16))
# (42, 'NOSOTROS DOS EN LA TORMENTA', 'https://cuspide.com/producto/nosotros-dos-en-la-tormenta/', 15999.0, 19.49, 16.49, datetime.date(2023, 12, 16))
# (43, 'LOS CUATRO ACUERDOS', 'https://cuspide.com/producto/los-cuatro-acuerdos/', 10690.0, 13.02, 11.02, datetime.date(2023, 12, 16))
# (44, 'ESCRIBIR UN SILENCIO', 'https://cuspide.com/producto/escribir-un-silencio/', 12999.0, 15.83, 13.4, datetime.date(2023, 12, 16))
# (45, 'EL CAMINO DEL ARTISTA', 'https://cuspide.com/producto/el-camino-del-artista/', 13899.0, 16.93, 14.33, datetime.date(2023, 12, 16))
# (46, 'LOS ARBOLES CAIDOS TAMBIEN SON DEL BOSQUE.', 'https://cuspide.com/producto/los-arboles-caidos-tambien-son-del-bosque/', 6840.0, 8.33, 7.05, datetime.date(2023, 12, 16))
# (47, 'TEMAS DE SIEMPRE', 'https://cuspide.com/producto/temas-de-siempre/', 16500.0, 20.1, 17.01, datetime.date(2023, 12, 16))
# (48, 'COMPAS 10 LOS COMPAS Y EL FIN DEL MULTIVERSO', 'https://cuspide.com/producto/compas-10-los-compas-y-el-fin-del-multiverso/', 16800.0, 20.46, 17.32, datetime.date(2023, 12, 16))
# (49, 'CUANDO NO QUEDEN MAS ESTRELLAS QUE CONTAR', 'https://cuspide.com/producto/cuando-no-queden-mas-estrellas-que-contar/', 10800.0, 13.15, 11.13, datetime.date(2023, 12, 16))
# (50, 'LOS SIETE MARIDOS DE EVELYN HUGO', 'https://cuspide.com/producto/los-siete-maridos-de-evelyn-hugo/', 13550.0, 16.5, 13.97, datetime.date(2023, 12, 16))
# (51, 'TRILOGIA', 'https://cuspide.com/producto/trilogia/', 11600.0, 14.13, 11.96, datetime.date(2023, 12, 16))
# (52, 'JULIO CORTAZAR Y CRIS', 'https://cuspide.com/producto/julio-cortazar-y-cris/', 11090.0, 13.51, 11.43, datetime.date(2023, 12, 16))
# (53, 'FORTUNA', 'https://cuspide.com/producto/fortuna/', 13800.0, 16.81, 14.23, datetime.date(2023, 12, 16))
# (54, 'CLASES DE LITERATURA RUSA', 'https://cuspide.com/producto/clases-de-literatura-rusa/', 12999.0, 15.83, 13.4, datetime.date(2023, 12, 16))
# (55, 'MI DESEO ES ODIARTE', 'https://cuspide.com/producto/mi-deseo-es-odiarte/', 9650.0, 11.75, 9.95, datetime.date(2023, 12, 16))
# (56, 'YOLO AVENTURAS 3 LOS IMPOSTORES DEL ESPACIO', 'https://cuspide.com/producto/yolo-aventuras-3-los-impostores-del-espacio/', 14000.0, 17.05, 14.43, datetime.date(2023, 12, 16))
# (57, 'POLITEIA', 'https://cuspide.com/producto/politeia-2/', 13500.0, 16.44, 13.92, datetime.date(2023, 12, 16))
# (58, 'LA SCALONETA', 'https://cuspide.com/producto/la-scaloneta/', 8490.0, 10.34, 8.75, datetime.date(2023, 12, 16))
# (59, 'LOS CHICOS DE BILOXI', 'https://cuspide.com/producto/los-chicos-de-biloxi/', 17599.0, 21.44, 18.14, datetime.date(2023, 12, 16))
# (60, 'PADRE RICO , PADRE POBRE (25 A/OS)', 'https://cuspide.com/producto/padre-rico-padre-pobre-25-a-os/', 10899.0, 13.28, 11.24, datetime.date(2023, 12, 16))
# (61, 'ENCUENTRA TU PERSONA VITAMINA', 'https://cuspide.com/producto/encuentra-tu-persona-vitamina/', 21800.0, 26.55, 22.47, datetime.date(2023, 12, 16))
# (62, 'PENSAR A LA JAPONESA', 'https://cuspide.com/producto/pensar-a-la-japonesa/', 6950.0, 8.47, 7.16, datetime.date(2023, 12, 16))
# (63, 'ME DESCUBRO A DIARIO', 'https://cuspide.com/producto/me-descubro-a-diario/', 22490.0, 27.39, 23.19, datetime.date(2023, 12, 16))
# (64, 'LAS LUCES DE FEBRERO', 'https://cuspide.com/producto/las-luces-de-febrero/', 14999.0, 18.27, 15.46, datetime.date(2023, 12, 16))
# (65, 'UN VECINO ANORMAL  : Y EL LADRON DEL CHOCOLATE', 'https://cuspide.com/producto/un-vecino-anormal-y-el-ladron-del-chocolate/', 6399.0, 7.79, 6.6, datetime.date(2023, 12, 16))
# (66, 'EL PRINCIPITO', 'https://cuspide.com/producto/el-principito-9/', 3999.0, 4.87, 4.12, datetime.date(2023, 12, 16))
# (67, 'LA CASA DE LOS SUICIDIOS', 'https://cuspide.com/producto/la-casa-de-los-suicidios/', 13900.0, 16.93, 14.33, datetime.date(2023, 12, 16))
# (68, 'LAS HIJAS DE LA CRIADA', 'https://cuspide.com/producto/las-hijas-de-la-criada/', 18100.0, 22.05, 18.66, datetime.date(2023, 12, 16))
# (69, 'PENSAMIENTOS NUTRITIVOS', 'https://cuspide.com/producto/pensamientos-nutritivos/', 8999.0, 10.96, 9.28, datetime.date(2023, 12, 16))
# (70, '1. HARRY POTTER Y LA PIEDRA FILOSOFAL ( BOLSILLO )', 'https://cuspide.com/producto/1-harry-potter-y-la-piedra-filosofal-bolsillo/', 9999.0, 12.18, 10.31, datetime.date(2023, 12, 16))
# (71, 'PORQUE DEMASIADO NO ES SUFICIENTE', 'https://cuspide.com/producto/porque-demasiado-no-es-suficiente/', 9990.0, 12.17, 10.3, datetime.date(2023, 12, 16))
# (72, 'TESIS SOBRE UNA DOMESTICACION', 'https://cuspide.com/producto/tesis-sobre-una-domesticacion/', 18500.0, 22.53, 19.07, datetime.date(2023, 12, 16))
# (73, 'LA ARMADURA DE LA LUZ', 'https://cuspide.com/producto/la-armadura-de-la-luz/', 24999.0, 30.45, 25.77, datetime.date(2023, 12, 16))
# (74, 'SANA A TUS ANTEPASADOS PARA SANAR TU VIDA', 'https://cuspide.com/producto/sana-a-tus-antepasados-para-sanar-tu-vida/', 8150.0, 9.93, 8.4, datetime.date(2023, 12, 16))
# (75, 'LAS MALAS - BOOKET VERANO 2023-2024', 'https://cuspide.com/producto/las-malas-booket-verano-2023-2024/', 9000.0, 10.96, 9.28, datetime.date(2023, 12, 16))
# (76, 'MESSIMANIA', 'https://cuspide.com/producto/messimania/', 11600.0, 14.13, 11.96, datetime.date(2023, 12, 16))
# (77, 'LOS VESTIDOS APONI - STICKERS', 'https://cuspide.com/producto/los-vestidos-aponi-stickers/', 7999.0, 9.74, 8.25, datetime.date(2023, 12, 16))
# (78, 'LA TERCERA  LOS HEROES', 'https://cuspide.com/producto/la-tercera-los-heroes/', 12400.0, 15.1, 12.78, datetime.date(2023, 12, 16))
# (79, 'NOSOTROS EN LA LUNA', 'https://cuspide.com/producto/nosotros-en-la-luna-2/', 9000.0, 10.96, 9.28, datetime.date(2023, 12, 16))
# (80, 'EL ETERNAUTA ( ED . ECONOMICA )', 'https://cuspide.com/producto/el-eternauta-ed-economica/', 14300.0, 17.42, 14.74, datetime.date(2023, 12, 16))
# (81, 'COMETIERRA 10 EDIC', 'https://cuspide.com/producto/cometierra-10-edic/', 9300.0, 11.33, 9.59, datetime.date(2023, 12, 16))
# (82, 'LA HERMANDAD DE LAS MALAS HIJAS', 'https://cuspide.com/producto/la-hermandad-de-las-malas-hijas/', 13799.0, 16.81, 14.23, datetime.date(2023, 12, 16))
# (83, 'TEORIA DE LA GRAVEDAD', 'https://cuspide.com/producto/teoria-de-la-gravedad/', 10900.0, 13.28, 11.24, datetime.date(2023, 12, 16))
# (84, 'BAJAR ES LO PEOR', 'https://cuspide.com/producto/bajar-es-lo-peor/', 12350.0, 15.04, 12.73, datetime.date(2023, 12, 16))
# (85, 'LAS INDIGNAS', 'https://cuspide.com/producto/las-indignas/', 8399.0, 10.23, 8.66, datetime.date(2023, 12, 16))
# (86, 'MUCHAS VIDAS , MUCHOS MAESTROS', 'https://cuspide.com/producto/muchas-vidas-muchos-maestros-2/', 9499.0, 11.57, 9.79, datetime.date(2023, 12, 16))
# (87, 'RIVALES DIVINOS', 'https://cuspide.com/producto/rivales-divinos/', 13790.0, 16.8, 14.22, datetime.date(2023, 12, 16))
# (88, 'UN ALMA DE CENIZA Y SANGRE  ( LIBRO 5 SAGA DE SANGRE Y CENIZAS )', 'https://cuspide.com/producto/un-alma-de-ceniza-y-sangre-libro-5-saga-de-sangre-y-cenizas/', 15400.0, 18.76, 15.88, datetime.date(2023, 12, 16))
# (89, 'BEYOND THE STORY ( EDICION EN ESPA/OL )', 'https://cuspide.com/producto/beyond-the-story-edicion-en-espa-ol/', 14999.0, 18.27, 15.46, datetime.date(2023, 12, 16))
# (90, 'TOKIO BLUES - BOOKET VERANO 2023-2024', 'https://cuspide.com/producto/tokio-blues-booket-verano-2023-2024/', 9000.0, 10.96, 9.28, datetime.date(2023, 12, 16))
# Datos de la tabla errors:
# (1, 'LO MEJOR Y LO PEOR DE INTERNET', 'https://cuspide.com/producto/lo-mejor-y-lo-peor-de-internet/', datetime.date(2023, 12, 16), "'NoneType' object has no attribute 'find'")
# (2, 'HABITOS ATOMICOS', 'https://cuspide.com/producto/habitos-atomicos-2/', datetime.date(2023, 12, 16), "'NoneType' object has no attribute 'find'")
# (3, 'LOS JUEGOS DEL HAMBRE ( LIBRO 1 DE LA SAGA LOS JUEGOS DEL HAMBRE )', 'https://cuspide.com/producto/los-juegos-del-hambre-libro-1-de-la-saga-los-juegos-del-hambre/', datetime.date(2023, 12, 16), "'NoneType' object has no attribute 'find'")
# (4, 'EL SUTIL ARTE DE QUE ( CASI TODO ) TE IMPORTE UNA MIERDA', 'https://cuspide.com/producto/el-sutil-arte-de-que-casi-todo-te-importe-una-mierda/', datetime.date(2023, 12, 16), "'NoneType' object has no attribute 'find'")
# (5, 'TAYLOR : FROM THE VAULT', 'https://cuspide.com/producto/taylor-from-the-vault/', datetime.date(2023, 12, 16), "'NoneType' object has no attribute 'find'")
# (6, 'SI LO CREES , LO CREAS', 'https://cuspide.com/producto/si-lo-crees-lo-creas/', datetime.date(2023, 12, 16), "'NoneType' object has no attribute 'find'")
# (7, 'DEJA DE SER TU', 'https://cuspide.com/producto/deja-de-ser-tu/', datetime.date(2023, 12, 16), "'NoneType' object has no attribute 'find'")
# (8, 'LAS NI/AS DEL NARANJEL', 'https://cuspide.com/producto/las-ni-as-del-naranjel/', datetime.date(2023, 12, 16), "'NoneType' object has no attribute 'find'")
# (9, 'ARTA EN EL APOCALIPSIS MAXIMO ( LIBRO 1 DE ARTA )', 'https://cuspide.com/producto/arta-en-el-apocalipsis-maximo-libro-1-de-arta/', datetime.date(2023, 12, 16), "'NoneType' object has no attribute 'find'")
# (10, 'BALADA DE PAJAROS CANTORES Y SERPIENTES', 'https://cuspide.com/producto/balada-de-pajaros-cantores-y-serpientes/', datetime.date(2023, 12, 16), "'NoneType' object has no attribute 'find'")
# Conexión cerrada
